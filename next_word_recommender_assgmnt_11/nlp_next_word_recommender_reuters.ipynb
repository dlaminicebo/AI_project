# %%
# loading the required libraries
import pandas as pd
import numpy as np
import re
import pickle
import random
from tqdm import tqdm

pd.set_option('display.width', 500)

# %%
# mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def print_df(df):
    print(df.head())
    print(df.shape)
    print(df.info())

# %%
# open text file and read in data
#with open("drive/My Drive/dialogs_dataset", "rb") as f:
#with open("drive/MyDrive/Colab Notebooks/Project - Next  Word Recommender System/dialogs_dataset", "rb") as f:
#    dialogs = pickle.load(f)

df_reuters = pd.read_csv("drive/MyDrive/Colab Notebooks/Project - Next  Word Recommender System/sample_reuters_dataset.csv")
print_df(df_reuters)
# Out:
#    sentence_number                                      sentence_text
# 0                0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                1  They told Reuter correspondents in Asian capit...
# 2                2  But some exporters said that while the conflic...
# 3                3  The U . S . Has said it will impose 300 mln dl...
# 4                4  Unofficial Japanese estimates put the impact o...
# (10000, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentence_number  10000 non-null  int64
#  1   sentence_text    10000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB
# None

# %%
# text cleaning
def clean_data(text):
    # remove everything except alphabets, ' and white spaces
    text = re.sub("[^a-zA-Z' ]", "", text)
    # convert text to lowercase
    text = text.lower()
    return text

df_reuters["clean_sentences"] = df_reuters['sentence_text'].apply(clean_data)
print_df(df_reuters)
# Out:
#    sentence_number                                      sentence_text                                    clean_sentences
# 0                0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...  asian exporters fear damage from u  s  japan r...
# 1                1  They told Reuter correspondents in Asian capit...  they told reuter correspondents in asian capit...
# 2                2  But some exporters said that while the conflic...  but some exporters said that while the conflic...
# 3                3  The U . S . Has said it will impose 300 mln dl...  the u  s  has said it will impose  mln dlrs of...
# 4                4  Unofficial Japanese estimates put the impact o...  unofficial japanese estimates put the impact o...
# (10000, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sentence_number  10000 non-null  int64
#  1   sentence_text    10000 non-null  object
#  2   clean_sentences  10000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB
# None

# %%
# creating the vocabulary
# get list of all the words
all_words = " ".join(df_reuters['clean_sentences']).split()
print(type(all_words))

words_dict = {}

# add word-count pair to the dictionary
for word in all_words:
    # check if the word is already in dictionary
    if word in words_dict:
        # increment count of word by 1
        words_dict[word] = words_dict[word] + 1
    else:
        # add the word to dictionary with count 1
        words_dict[word] = 1

print(words_dict)

# prepare a dataframe
words_df = pd.DataFrame({'word':list(words_dict.keys()), 'count':list(words_dict.values())})

# sort words by their count in increasing order
words_df = words_df.sort_values(by = ['count'])

# reset dataframe index
words_df.reset_index(inplace = True, drop=True)

# words with least frequency
print(words_df.head())

# words with highest frequency
print(words_df.tail())

# vocabulary size
print("vocabulary size:", len(words_df))
# Out:
# <class 'list'>
# {'asian': 13, 'exporters': 52, 'fear': 8, 'damage': 29, 'from': 1369, 'u': 1117, 's': 2864, 'japan': 441, 'rift': 1, 'mounting': 5, 'trade': 549, 'friction': 8, 'between': 191, 'the': 12496, 'and': 4599, 'has': 974, 'raised': 70, 'fears': 13, 'among': 44, 'many': 54, 'of': 6671, 'asia': 14, "'": 2094, 'exporting': 12, 'n
': 25, 'sales': 371, 'hong': 26, 'kong': 26, 'where': 60, 'newspapers': 5, 'have': 542, 'been': 396, 'selling': 42, 'manufacturers': 15, 'share': 516, 'view': 40, 'other': 331, 'such': 100, 'commercial': 41, 'advantage': 8, 'outweighed': 2, 'further': 172, 'block': 19, 'is': 1420, 'very': 72, 'lawrence': 2, 'mills': 17, 'director': 41, 'general': 86, 'federation': 20, 'industry': 200, 'whole': 20, 'purpose': 9, 'prevent': 30, 'one': 508, 'day': 132, 'extended': 19, 'sources': 161, 'much': 92, 'more': 354, 'serious': 13, 'disadvantage': 2, 'action': 82, 'restraining': 2, 'he': 971, 'was': 1127, 'biggest': 24, 'export': 152, 'market': 498, 'accounting': 24, 'over': 236, 'domestically': 5, 'produced': 45, 'australian': 56, 'government': 304, 'awaiting': 9, 'outcome': 12, 'talks': 112, 'interest': 252, 'concern': 39, 'minister': 122, 'john': 24, 'button': 2, 'canberra': 1, 'friday': 44, 'this': 642, 'kind': 13, 'deterioration': 6, 'relations': 13, 'two': 444, 'which': 643, 'trading': 141, 'partners': 57, 'ours': 2,  ...
#           word  count
# 0        ulcer      1
# 1        gaons      1
# 2  securitiesd      1
# 3   unfiltered      1
# 4   preceeding      1
#        word  count
# 12575  said   4649
# 12576    in   5070
# 12577    to   6337
# 12578    of   6671
# 12579   the  12496
# vocabulary size: 12580

# %%
# creating an empty dataframe
dataset = pd.DataFrame()

# adding cleaned sentences in the dataframe
dataset['Sentences'] = df_reuters['clean_sentences']

# first 20 cleaned sentences
print(dataset.head(10))

# using .split() to get tokens from the sentence
dataset['Sentences'][0].split()
# Out:
#                                            Sentences
# 0  asian exporters fear damage from u  s  japan r...
# 1  they told reuter correspondents in asian capit...
# 2  but some exporters said that while the conflic...
# 3  the u  s  has said it will impose  mln dlrs of...
# 4  unofficial japanese estimates put the impact o...
# 5   we wouldn ' t be able to do business  said a ...
# 6   if the tariffs remain in place for any length...
# 7  in taiwan  businessmen and officials are also ...
# 8       we are aware of the seriousness of the u  s
# 9  threat against japan because it serves as a wa...
# ['asian',
#  'exporters',
#  'fear',
#  'damage',
#  'from',
#  'u',
#  's',
#  'japan',
#  'rift',
#  'mounting',
#  'trade',
#  'friction',
#  'between',
#  'the',
#  'u',
#  's',
#  'and',
#  'japan',
#  'has',
#  'raised',
#  'fears',
#  'among',
#  'many',
#  'of',
#  'asia',
#  "'",
#  's',
#  'exporting',
#  'nations',
#  'that',
#  'the',
#  'row',
#  'could',
#  'inflict',
#  'far',
#  'reaching',
#  'economic',
#  'damage',
#  'businessmen',
#  'and',
#  'officials',
#  'said']

# %%
# function to create unigrams
# taking a sentence as input
def create_unigram(sentence):
    # creating tokens from the sentence
    tokens = sentence.split()
    # empty list to store the unigrams
    unigram_list = []
    # number of unigrams is equal to the number of tokens in the sentence
    for i in range(len(tokens)):
        # appending each unigram in the list
        unigram_list.append(tokens[i:i+1])
    # returning the unigram list for a sentence
    return unigram_list

# %%
# function to create bigrams
def create_bigram(sentence):
    tokens = sentence.split()
    bigram_list = []
    # number of bigrams is one less than the number of tokens in the sentence
    for i in range(len(tokens)-1):
        bigram_list.append(tokens[i:i+2])
        #print(tokens[i:i+2])
    return bigram_list

# %%
# function to create trigrams
def create_trigram(sentence):
    tokens = sentence.split()
    trigram_list = []
    # number of trigrams is two less than the number of tokens in the sentence
    for i in range(len(tokens)-2):
        trigram_list.append(tokens[i:i+3])
    return trigram_list

# %%
# creating unigrams for all the sentences in the dataset
final_unigram = []
# for each sentence
for i in range(dataset.shape[0]):
    # using the defined unigram function to create unigrams
    final_unigram.append(create_unigram(dataset['Sentences'][i]))

# adding the unigram in a seperate column in the dataset
dataset['unigram'] = final_unigram

# %%
# creating bigrams for all the sentences in the dataset
final_bigram = []
for i in range(dataset.shape[0]):
    final_bigram.append(create_bigram(dataset['Sentences'][i]))

dataset['bigram'] = final_bigram

# %%
# creating trigrams for all the sentences in the dataset
final_trigram = []
for i in range(dataset.shape[0]):
    final_trigram.append(create_trigram(dataset['Sentences'][i]))

dataset['trigram'] = final_trigram

# %%
# first 20 rows of the dataset
dataset.head(20)
# Out:
#                                             Sentences                                            unigram                                             bigram                                            trigram
# 0   asian exporters fear damage from u  s  japan r...  [[asian], [exporters], [fear], [damage], [from...  [[asian, exporters], [exporters, fear], [fear,...  [[asian, exporters, fear], [exporters, fear, d...
# 1   they told reuter correspondents in asian capit...  [[they], [told], [reuter], [correspondents], [...  [[they, told], [told, reuter], [reuter, corres...  [[they, told, reuter], [told, reuter, correspo...
# 2   but some exporters said that while the conflic...  [[but], [some], [exporters], [said], [that], [...  [[but, some], [some, exporters], [exporters, s...  [[but, some, exporters], [some, exporters, sai...
# 3   the u  s  has said it will impose  mln dlrs of...  [[the], [u], [s], [has], [said], [it], [will],...  [[the, u], [u, s], [s, has], [has, said], [sai...  [[the, u, s], [u, s, has], [s, has, said], [ha...
# 4   unofficial japanese estimates put the impact o...  [[unofficial], [japanese], [estimates], [put],...  [[unofficial, japanese], [japanese, estimates]...  [[unofficial, japanese, estimates], [japanese,...
# 5    we wouldn ' t be able to do business  said a ...  [[we], [wouldn], ['], [t], [be], [able], [to],...  [[we, wouldn], [wouldn, '], [', t], [t, be], [...  [[we, wouldn, '], [wouldn, ', t], [', t, be], ...
# 6    if the tariffs remain in place for any length...  [[if], [the], [tariffs], [remain], [in], [plac...  [[if, the], [the, tariffs], [tariffs, remain],...  [[if, the, tariffs], [the, tariffs, remain], [...
# 7   in taiwan  businessmen and officials are also ...  [[in], [taiwan], [businessmen], [and], [offici...  [[in, taiwan], [taiwan, businessmen], [busines...  [[in, taiwan, businessmen], [taiwan, businessm...
# 8        we are aware of the seriousness of the u  s   [[we], [are], [aware], [of], [the], [seriousne...  [[we, are], [are, aware], [aware, of], [of, th...  [[we, are, aware], [are, aware, of], [aware, o...
# 9   threat against japan because it serves as a wa...  [[threat], [against], [japan], [because], [it]...  [[threat, against], [against, japan], [japan, ...  [[threat, against, japan], [against, japan, be...
# 10  taiwan had a trade trade surplus of    billion...  [[taiwan], [had], [a], [trade], [trade], [surp...  [[taiwan, had], [had, a], [a, trade], [trade, ...  [[taiwan, had, a], [had, a, trade], [a, trade,...
# 11  the surplus helped swell taiwan ' s foreign ex...  [[the], [surplus], [helped], [swell], [taiwan]...  [[the, surplus], [surplus, helped], [helped, s...  [[the, surplus, helped], [surplus, helped, swe...
# 12   we must quickly open our markets  remove trad...  [[we], [must], [quickly], [open], [our], [mark...  [[we, must], [must, quickly], [quickly, open],...  [[we, must, quickly], [must, quickly, open], [...
# 13  retaliation  said paul sheen  chairman of text...  [[retaliation], [said], [paul], [sheen], [chai...  [[retaliation, said], [said, paul], [paul, she...  [[retaliation, said, paul], [said, paul, sheen...
# 14  a senior official of south korea ' s trade pro...  [[a], [senior], [official], [of], [south], [ko...  [[a, senior], [senior, official], [official, o...  [[a, senior, official], [senior, official, of]...
# 15  last year south korea had a trade surplus of  ...  [[last], [year], [south], [korea], [had], [a],...  [[last, year], [year, south], [south, korea], ...  [[last, year, south], [year, south, korea], [s...
# 16  in malaysia  trade officers and businessmen sa...  [[in], [malaysia], [trade], [officers], [and],...  [[in, malaysia], [malaysia, trade], [trade, of...  [[in, malaysia, trade], [malaysia, trade, offi...
# 17  in hong kong  where newspapers have alleged ja...  [[in], [hong], [kong], [where], [newspapers], ...  [[in, hong], [hong, kong], [kong, where], [whe...  [[in, hong, kong], [hong, kong, where], [kong,...
# 18  but other businessmen said such a short  term ...  [[but], [other], [businessmen], [said], [such]...  [[but, other], [other, businessmen], [business...  [[but, other, businessmen], [other, businessme...
# 19   that is a very short  term view  said lawrenc...  [[that], [is], [a], [very], [short], [term], [...  [[that, is], [is, a], [a, very], [very, short]...  [[that, is, a], [is, a, very], [a, very, short...

# %%
# sample sentence
print(dataset['Sentences'][0])
print(dataset['Sentences'][1])
print(dataset['Sentences'][2])

# unigram of the sentence
print("unigram", dataset['unigram'][0])
print("unigram", dataset['unigram'][1])

# bigram of the sentence
print("bigram", dataset['bigram'][0])
print("bigram", dataset['bigram'][1])

# trigram of the sentence
print("trigram", dataset['trigram'][0])
print("trigram", dataset['trigram'][1])
# Out:
# asian exporters fear damage from u  s  japan rift mounting trade friction between the u  s  and japan has raised fears among many of asia ' s exporting nations that the row could inflict far  reaching economic damage  businessmen and officials said
# they told reuter correspondents in asian capitals a u  s  move against japan might boost protectionist sentiment in the u  s  and lead to curbs on american imports of their products
# but some exporters said that while the conflict would hurt them in the long  run  in the short  term tokyo ' s loss might be their gain
# unigram [['asian'], ['exporters'], ['fear'], ['damage'], ['from'], ['u'], ['s'], ['japan'], ['rift'], ['mounting'], ['trade'], ['friction'], ['between'], ['the'], ['u'], ['s'], ['and'], ['japan'], ['has'], ['raised'], ['fears'], ['among'], ['many'], ['of'], ['asia'], ["'"], ['s'], ['exporting'], ['nations'], ['that'], ['the'], ['row'], ['could'], ['inflict'], ['far'], ['reaching'], ['economic'], ['damage'], ['businessmen'], ['and'], ['officials'], ['said']]
# unigram [['they'], ['told'], ['reuter'], ['correspondents'], ['in'], ['asian'], ['capitals'], ['a'], ['u'], ['s'], ['move'], ['against'], ['japan'], ['might'], ['boost'], ['protectionist'], ['sentiment'], ['in'], ['the'], ['u'], ['s'], ['and'], ['lead'], ['to'], ['curbs'], ['on'], ['american'], ['imports'], ['of'], ['their'], ['products']]
# bigram [['asian', 'exporters'], ['exporters', 'fear'], ['fear', 'damage'], ['damage', 'from'], ['from', 'u'], ['u', 's'], ['s', 'japan'], ['japan', 'rift'], ['rift', 'mounting'], ['mounting', 'trade'], ['trade', 'friction'], ['friction', 'between'], ['between', 'the'], ['the', 'u'], ['u', 's'], ['s', 'and'], ['and', 'japan'], ['japan', 'has'], ['has', 'raised'], ['raised', 'fears'], ['fears', 'among'], ['among', 'many'], ['many', 'of'], ['of', 'asia'], ['asia', "'"], ["'", 's'], ['s', 'exporting'], ['exporting', 'nations'], ['nations', 'that'], ['that', 'the'], ['the', 'row'], ['row', 'could'], ['could', 'inflict'], ['inflict', 'far'], ['far', 'reaching'], ['reaching', 'economic'], ['economic', 'damage'], ['damage', 'businessmen'], ['businessmen', 'and'], ['and', 'officials'], ['officials', 'said']]
# bigram [['they', 'told'], ['told', 'reuter'], ['reuter', 'correspondents'], ['correspondents', 'in'], ['in', 'asian'], ['asian', 'capitals'], ['capitals', 'a'], ['a', 'u'], ['u', 's'], ['s', 'move'], ['move', 'against'], ['against', 'japan'], ['japan', 'might'], ['might', 'boost'], ['boost', 'protectionist'], ['protectionist', 'sentiment'], ['sentiment', 'in'], ['in', 'the'], ['the', 'u'], ['u', 's'], ['s', 'and'], ['and', 'lead'], ['lead', 'to'], ['to', 'curbs'], ['curbs', 'on'], ['on', 'american'], ['american', 'imports'], ['imports', 'of'], ['of', 'their'], ['their', 'products']]
# trigram [['asian', 'exporters', 'fear'], ['exporters', 'fear', 'damage'], ['fear', 'damage', 'from'], ['damage', 'from', 'u'], ['from', 'u', 's'], ['u', 's', 'japan'], ['s', 'japan', 'rift'], ['japan', 'rift', 'mounting'], ['rift', 'mounting', 'trade'], ['mounting', 'trade', 'friction'], ['trade', 'friction', 'between'], ['friction', 'between', 'the'], ['between', 'the', 'u'], ['the', 'u', 's'], ['u', 's', 'and'], ['s', 'and', 'japan'], ['and', 'japan', 'has'], ['japan', 'has', 'raised'], ['has', 'raised', 'fears'], ['raised', 'fears', 'among'], ['fears', 'among', 'many'], ['among', 'many', 'of'], ['many', 'of', 'asia'], ['of', 'asia', "'"], ['asia', "'", 's'], ["'", 's', 'exporting'], ['s', 'exporting', 'nations'], ['exporting', 'nations', 'that'], ['nations', 'that', 'the'], ['that', 'the', 'row'], ['the', 'row', 'could'], ['row', 'could', 'inflict'], ['could', 'inflict', 'far'], ['inflict', 'far', 'reaching'], ['far', 'reaching', 'economic'], ['reaching', 'economic', 'damage'], ['economic', 'damage', 'businessmen'], ['damage', 'businessmen', 'and'], ['businessmen', 'and', 'officials'], ['and', 'officials', 'said']]
# trigram [['they', 'told', 'reuter'], ['told', 'reuter', 'correspondents'], ['reuter', 'correspondents', 'in'], ['correspondents', 'in', 'asian'], ['in', 'asian', 'capitals'], ['asian', 'capitals', 'a'], ['capitals', 'a', 'u'], ['a', 'u', 's'], ['u', 's', 'move'], ['s', 'move', 'against'], ['move', 'against', 'japan'], ['against', 'japan', 'might'], ['japan', 'might', 'boost'], ['might', 'boost', 'protectionist'], ['boost', 'protectionist', 'sentiment'], ['protectionist', 'sentiment', 'in'], ['sentiment', 'in', 'the'], ['in', 'the', 'u'], ['the', 'u', 's'], ['u', 's', 'and'], ['s', 'and', 'lead'], ['and', 'lead', 'to'], ['lead', 'to', 'curbs'], ['to', 'curbs', 'on'], ['curbs', 'on', 'american'], ['on', 'american', 'imports'], ['american', 'imports', 'of'], ['imports', 'of', 'their'], ['of', 'their', 'products']]

# %%
# for defining the N-gram model
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance
for i in range(dataset.shape[0]):
    # for each trigram pair
    for w1, w2, w3 in create_trigram(dataset['Sentences'][i]):
        # count the occurance of word 3, given word 1 and word 2
        model[(w1, w2)][w3] += 1

# %%
print(dict(model["they", "told"]))
print(dict(model["they", "are"]))
# Out:
# {'reuter': 1, 'reporters': 1, 'reuters': 1}
# {'more': 1, 'prepared': 1, 'giving': 1, 'rumors': 1, 'to': 1, 'pleased': 1, 'a': 1, 'not': 4, 'saying': 1, 'trading': 1, 'free': 1, 'today': 1, 'beginning': 1, 'at': 1, 'willing': 2, 'happy': 1, 'required': 1, 'polysaturated': 1, 'defeathered': 1, 'fired': 2, 'imported': 1, 'unprofitable': 1, 'being': 1, 'less': 1}

# %%
# creating the unigram list
unigram_dict = {}
for i in tqdm(range(dataset.shape[0])):
    # add word-count pair to the dictionary
    for word in dataset['unigram'][i]:
        # check if the word is already in dictionary
        if word[0] in unigram_dict:
            # increment count of word by 1
            unigram_dict[word[0]] = unigram_dict[word[0]] + 1
        else:
            # add the word to dictionary with count 1
            unigram_dict[word[0]] = 1

unigram_dict
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 46623.06it/s]
# {'asian': 13,
#  'exporters': 52,
#  'fear': 8,
#  'damage': 29,
#  'from': 1369,
#  'u': 1117,
#  's': 2864,
#  'japan': 441,
#  'rift': 1,
#  'mounting': 5,
#  'trade': 549,
#  'friction': 8,
#  'between': 191,
#  'the': 12496,
#  'and': 4599,
#  'has': 974,
#  'raised': 70,
#  'fears': 13,
#  'among': 44,
#  'many': 54,
#  'of': 6671,
#  'asia': 14,
#  "'": 2094,
#  'exporting': 12,
#  'nations': 71,
#  'that': 1376,
#  'row': 3,
#  'could': 291,
#  'inflict': 1,
#  'far': 55,
#  'reaching': 7,
#  'economic': 244,
#  'businessmen': 15,
#  'officials': 190,
#  'said': 4649,
#  'they': 518,
#  'told': 237,
#  'reuter': 27,
#  'correspondents': 3,
#  'in': 5070,
#  'capitals': 3,
#  'a': 4412,
#  'move': 101,
#  'against': 270,
#  'might': 59,
#  'boost': 45,
#  'protectionist': 22,
#  'sentiment': 10,
#  'lead': 96,
#  'to': 6337,
#  'curbs': 12,
#  'on': 1643,
#  'american': 126,
#  'imports': 242,
#  'their': 230,
#  'products': 200,
#  'but': 650,
#  'some': 278,
#  'while': 164,
#  'conflict': 3,
#  'would': 926,
#  'hurt': 11,
#  'them': 58,
#  'long': 119,
#  'run': 21,
#  'short': 87,
#  'term': 120,
#  'tokyo': 75,
#  'loss': 607,
#  'be': 1165,
#  'gain': 101,
#  'it': 1970,
#  'will': 984,
#  'impose': 20,
#  'mln': 3064,
#  'dlrs': 2140,
#  'tariffs': 82,
#  'japanese': 192,
#  'electronics': 25,
#  'goods': 69,
#  'april': 477,
#  'retaliation': 20,
#  'for': 2592,
#  'alleged': 11,
#  'failure': 23,
#  'stick': 1,
#  'pact': 59,
#  'not': 838,
#  'sell': 139,
#  'semiconductors': 9,
#  'world': 166,
#  'markets': 182,
#  'at': 1311,
#  'below': 66,
#  'cost': 86,
#  'unofficial': 1,
#  'estimates': 62,
#  'put': 59,
#  'impact': 52,
#  'billion': 1112,
#  'spokesmen': 3,
#  'major': 206,
#  'firms': 57,
#  'virtually': 14,
#  'halt': 10,
#  'exports': 294,
#  'hit': 37,
#  'by': 1375,
#  'new': 474,
#  'taxes': 29,
#  'we': 258,
#  'wouldn': 6,
#  't': 115,
#  'able': 31,
#  'do': 90,
#  'business': 171,
#  'spokesman': 166,
#  'leading': 49,
#  'firm': 114,
#  'matsushita': 1,
#  'electric': 35,
#  'industrial': 120,
#  'co': 370,
#  'ltd': 273,
#  'lt': 1498,
#  'mc': 1,
#  'if': 282,
#  'remain': 55,
#  'place': 31,
#  'any': 142,
#  'length': 1,
#  'time': 145,
#  'beyond': 12,
#  'few': 42,
#  'months': 164,
#  'mean': 11,
#  'complete': 22,
#  'erosion': 2,
#  'subject': 72,
#  'tom': 4,
#  'murtha': 1,
#  'stock': 394,
#  'analyst': 60,
#  'office': 44,
#  'broker': 21,
#  'james': 33,
#  'capel': 2,
#  'taiwan': 62,
#  'are': 625,
#  'also': 442,
#  'worried': 15,
#  'aware': 7,
#  'seriousness': 3,
#  'threat': 11,
#  'because': 214,
#  'serves': 3,
#  'as': 884,
#  'warning': 5,
#  'us': 41,
#  'senior': 40,
#  'taiwanese': 4,
#  'official': 174,
#  'who': 98,
#  'asked': 74,
#  'named': 38,
#  'had': 512,
#  'surplus': 155,
#  'last': 654,
#  'year': 1212,
#  'pct': 1811,
#  'with': 1127,
#  'helped': 21,
#  'swell': 2,
#  'foreign': 253,
#  'exchange': 279,
#  'reserves': 153,
#  'largest': 79,
#  'must': 46,
#  'quickly': 18,
#  'open': 98,
#  'our': 101,
#  'remove': 9,
#  'barriers': 12,
#  'cut': 206,
#  'import': 67,
#  'allow': 40,
#  'want': 43,
#  'defuse': 2,
#  'problems': 55,
#  'possible': 72,
#  'paul': 21,
#  'sheen': 1,
#  'chairman': 145,
#  'textile': 32,
#  'safe': 3,
#  'group': 342,
#  'south': 135,
#  'korea': 49,
#  'promotion': 5,
#  'association': 53,
#  'dispute': 24,
#  'pressure': 57,
#  'whose': 21,
#  'chief': 51,
#  'similar': 36,
#  'those': 75,
#  'up': 386,
#  'malaysia': 21,
#  'officers': 17,
#  'tough': 23,
#  'hard': 37,
#  'producers': 72,
#  'third': 67,
#  'countries': 142,
#  'expand': 25,
#  'sales': 371,
#  'hong': 26,
#  'kong': 26,
#  'where': 60,
#  'newspapers': 5,
#  'have': 542,
#  'been': 396,
#  'selling': 42,
#  'manufacturers': 15,
#  'share': 516,
#  'view': 40,
#  'other': 331,
#  'such': 100,
#  'commercial': 41,
#  'advantage': 8,
#  'outweighed': 2,
#  'further': 172,
#  'block': 19,
#  'is': 1420,
#  'very': 72,
#  'lawrence': 2,
#  'mills': 17,
#  'director': 41,
#  'general': 86,
#  'federation': 20,
#  'industry': 200,
#  'whole': 20,
#  'purpose': 9,
#  'prevent': 30,
#  'one': 508,
#  'day': 132,
#  'extended': 19,
#  'sources': 161,
#  'much': 92,
#  'more': 354,
#  'serious': 13,
#  'disadvantage': 2,
#  'action': 82,
#  'restraining': 2,
#  'he': 971,
#  'was': 1127,
#  'biggest': 24,
#  'export': 152,
#  'market': 498,
#  'accounting': 24,
#  'over': 236,
#  'domestically': 5,
#  'produced': 45,
#  'australian': 56,
#  'government': 304,
#  'awaiting': 9,
#  'outcome': 12,
#  'talks': 112,
#  'interest': 252,
#  'concern': 39,
#  'minister': 122,
#  'john': 24,
#  'button': 2,
#  'canberra': 1,
#  'friday': 44,
#  'this': 642,
#  'kind': 13,
#  'deterioration': 6,
#  'relations': 13,
#  'two': 444,
#  'which': 643,
#  'trading': 141,
#  'partners': 57,
#  'ours': 2,
#  'matter': 16,
#  'australia': 55,
#  'concerns': 9,
#  'centred': 1,
#  'coal': 7,
#  'beef': 57,
#  'significant': 34,
#  'country': 103,
#  'meanwhile': 13,
#  'diplomatic': 10,
#  'manoeuvres': 1,
#  'solve': 5,
#  'stand': 14,
#  'off': 89,
#  'continue': 84,
#  'ruling': 30,
#  'liberal': 18,
#  'democratic': 17,
#  'party': 34,
#  'yesterday': 161,
#  'outlined': 12,
#  'package': 34,
#  'measures': 67,
#  'economy': 125,
#  'proposed': 106,
#  'include': 65,
#  'large': 70,
#  'supplementary': 5,
#  'budget': 117,
#  'record': 188,
#  'public': 84,
#  'works': 12,
#  'spending': 54,
#  'first': 447,
#  'half': 113,
#  'financial': 148,
#  'call': 28,
#  'stepped': 2,
#  'an': 844,
#  'emergency': 10,
#  'measure': 16,
#  'stimulate': 27,
#  'despite': 71,
#  'prime': 73,
#  'yasuhiro': 12,
#  'nakasone': 24,
#  'avowed': 1,
#  'fiscal': 90,
#  'reform': 31,
#  'program': 66,
#  'deputy': 16,
#  'representative': 19,
#  'michael': 12,
#  'smith': 12,
#  'makoto': 3,
#  'kuroda': 9,
#  'international': 221,
#  'miti': 17,
#  'due': 160,
#  'meet': 63,
#  'washington': 92,
#  'week': 334,
#  'effort': 31,
#  'end': 275,
#  'china': 106,
#  'daily': 65,
#  'says': 143,
#  'vermin': 2,
#  'eat': 2,
#  'grain': 130,
#  'stocks': 177,
#  'survey': 8,
#  'provinces': 6,
#  'seven': 147,
#  'cities': 4,
#  'showed': 48,
#  'consume': 3,
#  'each': 119,
#  'tonnes': 535,
#  'or': 553,
#  'fruit': 3,
#  'output': 107,
#  'left': 28,
#  'rot': 3,
#  'its': 1372,
#  'vegetables': 4,
#  'paper': 27,
#  'blamed': 7,
#  'waste': 14,
#  'inadequate': 10,
#  'storage': 18,
#  'bad': 6,
#  'preservation': 2,
#  'methods': 6,
#  'launched': 20,
#  'national': 197,
#  'programme': 13,
#  'reduce': 77,
#  'calling': 10,
#  'improved': 41,
#  'technology': 40,
#  'greater': 23,
#  'production': 289,
#  'additives': 2,
#  'gave': 44,
#  'no': 277,
#  'details': 57,
#  'revise': 8,
#  'energy': 93,
#  'demand': 177,
#  'downwards': 4,
#  'ministry': 108,
#  'supply': 158,
#  'outlook': 28,
#  'august': 39,
#  'forecast': 96,
#  'downtrend': 2,
#  'expected': 274,
#  'lower': 152,
#  'projection': 6,
#  'primary': 26,
#  'supplies': 60,
#  'kilolitres': 1,
#  'kl': 2,
#  'decision': 70,
#  'follows': 45,
#  'emergence': 1,
#  'structural': 8,
#  'changes': 43,
#  'following': 75,
#  'rise': 240,
#  'value': 106,
#  'yen': 193,
#  'decline': 74,
#  'domestic': 164,
#  'power': 30,
#  'planning': 24,
#  'work': 40,
#  'out': 148,
#  'revised': 45,
#  'through': 120,
#  'deliberations': 1,
#  'committee': 74,
#  'meetings': 29,
#  'agency': 38,
#  'natural': 50,
#  'resources': 43,
#  'review': 36,
#  'breakdown': 8,
#  'including': 101,
#  'oil': 586,
#  'nuclear': 2,
#  'gas': 158,
#  'provided': 25,
#  'bulk': 17,
#  'ended': 144,
#  'march': 315,
#  'supplying': 5,
#  'estimated': 105,
#  'kilowatt': 1,
#  'hour': 10,
#  'basis': 70,
#  'followed': 23,
#  'liquefied': 3,
#  'noted': 61,
#  'thai': 15,
#  'deficit': 213,
#  'widens': 3,
#  'quarter': 377,
#  'thailand': 27,
#  'widened': 6,
#  'baht': 3,
#  'ago': 129,
#  'economics': 9,
#  'department': 183,
#  'janunary': 1,
#  'rose': 227,
#  'climate': 4,
#  'resulted': 20,
#  'increase': 221,
#  'raw': 20,
#  'materials': 45,
#  'semi': 12,
#  'finished': 8,
#  'bill': 70,
#  'however': 137,
#  'fell': 126,
#  'prices': 387,
#  'expanded': 7,
#  'growth': 258,
#  'smaller': 17,
#  'than': 366,
#  'earnings': 177,
#  'key': 51,
#  'commodities': 30,
#  'rice': 72,
#  'declined': 61,
#  'maize': 41,
#  'sugar': 130,
#  'tin': 51,
#  'canned': 4,
#  'pineapples': 1,
#  'registering': 3,
#  'high': 150,
#  'were': 597,
#  'jewellery': 1,
#  'clothing': 4,
#  'rubber': 36,
#  'indonesia': 46,
#  'sees': 76,
#  'cpo': 5,
#  'price': 397,
#  'rising': 73,
#  'sharply': 46,
#  'expects': 98,
#  'crude': 160,
#  'palm': 32,
#  'tonne': 75,
#  'fob': 14,
#  'sometime': 3,
#  'better': 41,
#  'european': 121,
#  'fall': 111,
#  'malaysian': 11,
#  'hasrul': 1,
#  'harahap': 3,
#  'junior': 4,
#  'tree': 2,
#  'crops': 33,
#  'indonesian': 10,
#  'reporters': 47,
#  'sumatran': 1,
#  'now': 173,
#  'around': 164,
#  'cif': 7,
#  'delivery': 58,
#  'rotterdam': 13,
#  'traders': 133,
#  'maintain': 37,
#  'making': 73,
#  'recent': 102,
#  'purchases': 33,
#  'so': 103,
#  'possibly': 19,
#  'second': 82,
#  'producer': 59,
#  'after': 367,
#  'forced': 16,
#  'ensure': 9,
#  'during': 110,
#  'moslem': 1,
#  'fasting': 2,
#  'month': 250,
#  'ramadan': 2,
#  'cover': 28,
#  'temporary': 24,
#  'shortage': 20,
#  'lose': 7,
#  'calendar': 18,
#  'according': 54,
#  'central': 193,
#  'bank': 616,
#  'figures': 118,
#  'ship': 16,
#  'ban': 21,
#  'ends': 15,
#  'nsw': 10,
#  'ports': 18,
#  'tug': 5,
#  'crews': 3,
#  'wales': 5,
#  'victoria': 3,
#  'western': 68,
#  'lifted': 15,
#  'flag': 9,
#  'ships': 36,
#  'carrying': 12,
#  'containers': 2,
#  'still': 112,
#  'being': 97,
#  'disrupted': 7,
#  'separate': 19,
#  'shipping': 25,
#  'imposed': 26,
#  'pay': 151,
#  'claim': 8,
#  'prevented': 7,
#  'movement': 20,
#  'port': 50,
#  'nearly': 34,
#  'vessels': 20,
#  'went': 25,
#  'before': 141,
#  'hearing': 14,
#  'arbitration': 3,
#  'commission': 111,
#  'today': 275,
#  'disruption': 3,
#  'began': 46,
#  'cargo': 20,
#  'handling': 8,
#  'sydney': 5,
#  'newcastle': 3,
#  'kembla': 3,
#  'part': 96,
#  'called': 62,
#  'trades': 14,
#  'labour': 15,
#  'council': 58,
#  'protest': 9,
#  'state': 112,
#  'workers': 54,
#  'compensation': 12,
#  'laws': 14,
#  'various': 19,
#  'unions': 11,
#  'appear': 16,
#  'taking': 38,
#  'turn': 12,
#  'start': 100,
#  'shift': 10,
#  'then': 42,
#  'walk': 1,
#  'container': 4,
#  'movements': 9,
#  'most': 108,
#  'affected': 39,
#  'stopped': 9,
#  'altogether': 4,
#  'say': 97,
#  'how': 41,
#  'go': 43,
#  'what': 77,
#  'effect': 45,
#  'commodity': 49,
#  'may': 540,
#  'likely': 106,
#  'least': 45,
#  'paian': 1,
#  'nainggolan': 3,
#  'reuters': 92,
#  'telephone': 24,
#  'interview': 22,
#  'sawn': 1,
#  'timber': 5,
#  'pepper': 1,
#  'tobacco': 19,
#  'considered': 21,
#  'either': 22,
#  'refined': 23,
#  'introduced': 23,
#  'question': 19,
#  'rachmat': 1,
#  'saleh': 2,
#  'when': 169,
#  'ahead': 28,
#  'made': 174,
#  'fledgling': 1,
#  'currently': 57,
#  'coffee': 71,
#  'physicals': 3,
#  'outcry': 1,
#  'system': 102,
#  'four': 168,
#  'days': 128,
#  'several': 82,
#  'factors': 31,
#  'make': 91,
#  'cautiously': 2,
#  'slowly': 7,
#  'safely': 1,
#  'mistake': 2,
#  'undermine': 5,
#  'confidence': 21,
#  'physical': 9,
#  'added': 219,
#  'january': 106,
#  'contracts': 42,
#  'traded': 27,
#  'five': 245,
#  'forward': 29,
#  'robusta': 2,
#  'grades': 16,
#  'prompt': 2,
#  'board': 184,
#  'considering': 32,
#  'introduction': 10,
#  'futures': 64,
#  'later': 55,
#  'feasibility': 3,
#  'study': 28,
#  'needed': 50,
#  'decisions': 13,
#  'until': 62,
#  'elections': 6,
#  'monday': 25,
#  'should': 146,
#  'marketing': 72,
#  'hoped': 14,
#  'development': 89,
#  'help': 80,
#  'trying': 26,
#  'overseas': 25,
#  'building': 42,
#  'contacts': 5,
#  'users': 7,
#  'teams': 1,
#  'already': 82,
#  'encourage': 17,
#  'direct': 15,
#  'use': 119,
#  'delegation': 9,
#  'visit': 17,
#  'europe': 45,
#  'mexico': 22,
#  'latin': 4,
#  'states': 145,
#  'participation': 7,
#  'infant': 1,
#  'good': 71,
#  'although': 66,
#  'disappointing': 4,
#  'transactions': 24,
#  'december': 89,
#  'totalled': 26,
#  'worth': 51,
#  'plus': 32,
#  'rupiah': 3,
#  'delivered': 9,
#  'locally': 2,
#  'latest': 66,
#  'report': 209,
#  'amounted': 6,
#  'only': 175,
#  'lots': 4,
#  'valued': 15,
#  'total': 293,
#  'membership': 8,
#  'nine': 111,
#  'brokers': 25,
#  'sri': 14,
#  'lanka': 13,
#  'gets': 11,
#  'usda': 108,
#  'approval': 65,
#  'wheat': 189,
#  'food': 52,
#  'agriculture': 130,
#  'approved': 64,
#  'continental': 25,
#  'sale': 147,
#  'soft': 23,
#  'c': 76,
#  'f': 52,
#  'pacific': 39,
#  'northwest': 10,
#  'colombo': 6,
#  'shipment': 32,
#  'mining': 40,
#  'gold': 99,
#  'mine': 50,
#  'corp': 623,
#  'holdings': 56,
#  'wmng': 2,
#  'wmc': 6,
#  'establish': 5,
#  'joint': 55,
#  'venture': 46,
#  'northern': 19,
#  'territory': 2,
#  'about': 515,
#  'known': 23,
#  'goodall': 1,
#  'project': 14,
#  'owned': 125,
#  'local': 53,
#  'w': 17,
#  'r': 17,
#  'grace': 11,
#  'gra': 3,
#  'unit': 171,
#  'located': 15,
#  'kms': 2,
#  'east': 52,
#  'adelaide': 1,
#  'river': 23,
#  'mt': 11,
#  'bundey': 1,
#  'statement': 168,
#  'pit': 2,
#  'conventional': 3,
#  'leach': 1,
#  'treatment': 9,
#  'plant': 66,
#  'produce': 28,
#  'ounces': 17,
#  'mid': 26,
#  'annual': 101,
#  'ore': 24,
#  'capacity': 42,
#  'sumitomo': 16,
#  'aims': 6,
#  'quick': 7,
#  'recovery': 25,
#  'merger': 128,
#  'sumi': 1,
#  'certain': 63,
#  'status': 15,
#  'profitable': 21,
#  'result': 86,
#  'heiwa': 4,
#  'sogo': 4,
#  'analysts': 185,
#  'osaka': 2,
#  'based': 142,
#  'desposits': 1,
#  'trillion': 4,
#  'merged': 6,
#  'small': 40,
#  'struggling': 3,
#  'unrecoverable': 1,
#  'loans': 118,
#  'october': 53,
#  'link': 14,
#  'president': 137,
#  'koh': 1,
#  'komatsu': 9,
#  'confident': 9,
#  'his': 105,
#  'can': 116,
#  'regain': 1,
#  'position': 67,
#  'll': 4,
#  'back': 50,
#  'within': 63,
#  'three': 277,
#  'years': 159,
#  'initially': 8,
#  'profitability': 5,
#  'efficiency': 8,
#  'vastly': 1,
#  'branch': 10,
#  'network': 18,
#  'metropolitan': 4,
#  'area': 61,
#  'relatively': 16,
#  'weak': 24,
#  'divided': 9,
#  'whether': 52,
#  'gamble': 3,
#  'paid': 65,
#  'too': 53,
#  'debts': 4,
#  'others': 18,
#  'argue': 4,
#  'effective': 91,
#  'creating': 1,
#  'comparable': 10,
#  'scratch': 1,
#  'agreed': 155,
#  'aggressive': 8,
#  'entered': 32,
#  'lucrative': 4,
#  'securities': 151,
#  'geared': 2,
#  'competition': 21,
#  'questioned': 4,
#  'wisdom': 1,
#  'moves': 36,
#  've': 14,
#  'bold': 3,
#  'everything': 3,
#  'largely': 15,
#  'hands': 11,
#  'kleinwort': 5,
#  'benson': 2,
#  'simon': 3,
#  'smithson': 2,
#  'limits': 21,
#  'placed': 18,
#  'enter': 8,
#  'investment': 161,
#  'goldman': 5,
#  'sachs': 5,
#  'limited': 34,
#  'partnership': 30,
#  'federal': 145,
#  'reserve': 109,
#  'forbidden': 1,
#  'personnel': 7,
#  'tie': 4,
#  'widely': 7,
#  'looked': 5,
#  'lame': 1,
#  'duck': 1,
#  'fed': 165,
#  'stricter': 1,
#  'regulations': 12,
#  'change': 80,
#  'near': 41,
#  'future': 51,
#  'things': 7,
#  'wait': 4,
#  'st': 281,
#  'century': 13,
#  'willing': 13,
#  'patient': 4,
#  'routes': 7,
#  'into': 186,
#  'home': 43,
#  'article': 8,
#  'act': 32,
#  'version': 3,
#  'glass': 3,
#  'steagall': 1,
#  'separates': 2,
#  'banking': 54,
#  'walls': 1,
#  'crumbling': 1,
#  'hopes': 21,
#  'deregulation': 10,
#  'create': 7,
#  'opportunities': 12,
#  'need': 49,
#  'find': 22,
#  'chances': 5,
#  'cases': 12,
#  'these': 87,
#  'related': 28,
#  'trust': 56,
#  'occur': 10,
#  'focus': 16,
#  'bond': 50,
#  'dealing': 3,
#  'strengthening': 10,
#  'meiko': 1,
#  'holds': 32,
#  'optimistic': 18,
#  'entering': 8,
#  'here': 67,
#  'swiss': 40,
#  'universal': 8,
#  'subsidiary': 132,
#  'banca': 1,
#  'del': 9,
#  'gottardo': 2,
#  'finance': 112,
#  'grant': 6,
#  'licences': 12,
#  'subsidiaries': 19,
#  'banks': 149,
#  'soon': 36,
#  'parent': 26,
#  'less': 91,
#  'reluctant': 9,
#  'push': 14,
#  'don': 40,
#  'waves': 1,
#  'expect': 49,
#  'allowed': 22,
#  'like': 37,
#  'city': 38,
#  'pushing': 7,
#  'lending': 19,
#  'individuals': 8,
#  'medium': 27,
#  'businesses': 49,
#  'replace': 9,
#  'disappearing': 1,
#  'big': 15,
#  'devote': 1,
#  'lot': 16,
#  'digesting': 1,
#  'initiatives': 5,
#  'ailing': 3,
#  'strategies': 2,
#  'absorbing': 1,
#  'juggling': 1,
#  'next': 155,
#  'decade': 5,
#  'see': 58,
#  'strategy': 25,
#  'right': 33,
#  'wrong': 4,
#  'subroto': 3,
#  'supports': 6,
#  'extension': 24,
#  'mines': 25,
#  'confirmed': 22,
#  'support': 71,
#  'sixth': 10,
#  'agreement': 258,
#  'ita': 7,
#  'necessary': 24,
#  'clarify': 2,
#  'lapse': 2,
#  'ready': 15,
#  'seventh': 7,
#  'accord': 60,
#  'believe': 41,
#  'unnecessary': 2,
#  'expire': 17,
#  'june': 238,
#  'unless': 28,
#  'thirds': 5,
#  'majority': 24,
#  'members': 49,
#  'vote': 18,
#  'bundesbank': 84,
#  'allocates': 2,
#  'marks': 82,
#  'tender': 147,
#  'accepted': 23,
#  'bids': 33,
#  'repurchase': 49,
#  'fixed': 47,
#  ...}

# %%
# find the overall frequency of words in the corpus
counts = Counter(unigram_dict)
counts
# Out:
# Counter({'asian': 13,
#          'exporters': 52,
#          'fear': 8,
#          'damage': 29,
#          'from': 1369,
#          'u': 1117,
#          's': 2864,
#          'japan': 441,
#          'rift': 1,
#          'mounting': 5,
#          'trade': 549,
#          'friction': 8,
#          'between': 191,
#          'the': 12496,
#          'and': 4599,
#          'has': 974,
#          'raised': 70,
#          'fears': 13,
#          'among': 44,
#          'many': 54,
#          'of': 6671,
#          'asia': 14,
#          "'": 2094,
#          'exporting': 12,
#          'nations': 71,
#          'that': 1376,
#          'row': 3,
#          'could': 291,
#          'inflict': 1,
#          'far': 55,
#          'reaching': 7,
#          'economic': 244,
#          'businessmen': 15,
#          'officials': 190,
#          'said': 4649,
#          'they': 518,
#          'told': 237,
#          'reuter': 27,
#          'correspondents': 3,
#          'in': 5070,
#          'capitals': 3,
#          'a': 4412,
#          'move': 101,
#          'against': 270,
#          'might': 59,
#          'boost': 45,
#          'protectionist': 22,
#          'sentiment': 10,
#          'lead': 96,
#          'to': 6337,
#          'curbs': 12,
#          'on': 1643,
#          'american': 126,
#          'imports': 242,
#          'their': 230,
#          'products': 200,
#          'but': 650,
#          'some': 278,
#          'while': 164,
#          'conflict': 3,
#          'would': 926,
#          'hurt': 11,
#          'them': 58,
#          'long': 119,
#          'run': 21,
#          'short': 87,
#          'term': 120,
#          'tokyo': 75,
#          'loss': 607,
#          'be': 1165,
#          'gain': 101,
#          'it': 1970,
#          'will': 984,
#          'impose': 20,
#          'mln': 3064,
#          'dlrs': 2140,
#          'tariffs': 82,
#          'japanese': 192,
#          'electronics': 25,
#          'goods': 69,
#          'april': 477,
#          'retaliation': 20,
#          'for': 2592,
#          'alleged': 11,
#          'failure': 23,
#          'stick': 1,
#          'pact': 59,
#          'not': 838,
#          'sell': 139,
#          'semiconductors': 9,
#          'world': 166,
#          'markets': 182,
#          'at': 1311,
#          'below': 66,
#          'cost': 86,
#          'unofficial': 1,
#          'estimates': 62,
#          'put': 59,
#          'impact': 52,
#          'billion': 1112,
#          'spokesmen': 3,
#          'major': 206,
#          'firms': 57,
#          'virtually': 14,
#          'halt': 10,
#          'exports': 294,
#          'hit': 37,
#          'by': 1375,
#          'new': 474,
#          'taxes': 29,
#          'we': 258,
#          'wouldn': 6,
#          't': 115,
#          'able': 31,
#          'do': 90,
#          'business': 171,
#          'spokesman': 166,
#          'leading': 49,
#          'firm': 114,
#          'matsushita': 1,
#          'electric': 35,
#          'industrial': 120,
#          'co': 370,
#          'ltd': 273,
#          'lt': 1498,
#          'mc': 1,
#          'if': 282,
#          'remain': 55,
#          'place': 31,
#          'any': 142,
#          'length': 1,
#          'time': 145,
#          'beyond': 12,
#          'few': 42,
#          'months': 164,
#          'mean': 11,
#          'complete': 22,
#          'erosion': 2,
#          'subject': 72,
#          'tom': 4,
#          'murtha': 1,
#          'stock': 394,
#          'analyst': 60,
#          'office': 44,
#          'broker': 21,
#          'james': 33,
#          'capel': 2,
#          'taiwan': 62,
#          'are': 625,
#          'also': 442,
#          'worried': 15,
#          'aware': 7,
#          'seriousness': 3,
#          'threat': 11,
#          'because': 214,
#          'serves': 3,
#          'as': 884,
#          'warning': 5,
#          'us': 41,
#          'senior': 40,
#          'taiwanese': 4,
#          'official': 174,
#          'who': 98,
#          'asked': 74,
#          'named': 38,
#          'had': 512,
#          'surplus': 155,
#          'last': 654,
#          'year': 1212,
#          'pct': 1811,
#          'with': 1127,
#          'helped': 21,
#          'swell': 2,
#          'foreign': 253,
#          'exchange': 279,
#          'reserves': 153,
#          'largest': 79,
#          'must': 46,
#          'quickly': 18,
#          'open': 98,
#          'our': 101,
#          'remove': 9,
#          'barriers': 12,
#          'cut': 206,
#          'import': 67,
#          'allow': 40,
#          'want': 43,
#          'defuse': 2,
#          'problems': 55,
#          'possible': 72,
#          'paul': 21,
#          'sheen': 1,
#          'chairman': 145,
#          'textile': 32,
#          'safe': 3,
#          'group': 342,
#          'south': 135,
#          'korea': 49,
#          'promotion': 5,
#          'association': 53,
#          'dispute': 24,
#          'pressure': 57,
#          'whose': 21,
#          'chief': 51,
#          'similar': 36,
#          'those': 75,
#          'up': 386,
#          'malaysia': 21,
#          'officers': 17,
#          'tough': 23,
#          'hard': 37,
#          'producers': 72,
#          'third': 67,
#          'countries': 142,
#          'expand': 25,
#          'sales': 371,
#          'hong': 26,
#          'kong': 26,
#          'where': 60,
#          'newspapers': 5,
#          'have': 542,
#          'been': 396,
#          'selling': 42,
#          'manufacturers': 15,
#          'share': 516,
#          'view': 40,
#          'other': 331,
#          'such': 100,
#          'commercial': 41,
#          'advantage': 8,
#          'outweighed': 2,
#          'further': 172,
#          'block': 19,
#          'is': 1420,
#          'very': 72,
#          'lawrence': 2,
#          'mills': 17,
#          'director': 41,
#          'general': 86,
#          'federation': 20,
#          'industry': 200,
#          'whole': 20,
#          'purpose': 9,
#          'prevent': 30,
#          'one': 508,
#          'day': 132,
#          'extended': 19,
#          'sources': 161,
#          'much': 92,
#          'more': 354,
#          'serious': 13,
#          'disadvantage': 2,
#          'action': 82,
#          'restraining': 2,
#          'he': 971,
#          'was': 1127,
#          'biggest': 24,
#          'export': 152,
#          'market': 498,
#          'accounting': 24,
#          'over': 236,
#          'domestically': 5,
#          'produced': 45,
#          'australian': 56,
#          'government': 304,
#          'awaiting': 9,
#          'outcome': 12,
#          'talks': 112,
#          'interest': 252,
#          'concern': 39,
#          'minister': 122,
#          'john': 24,
#          'button': 2,
#          'canberra': 1,
#          'friday': 44,
#          'this': 642,
#          'kind': 13,
#          'deterioration': 6,
#          'relations': 13,
#          'two': 444,
#          'which': 643,
#          'trading': 141,
#          'partners': 57,
#          'ours': 2,
#          'matter': 16,
#          'australia': 55,
#          'concerns': 9,
#          'centred': 1,
#          'coal': 7,
#          'beef': 57,
#          'significant': 34,
#          'country': 103,
#          'meanwhile': 13,
#          'diplomatic': 10,
#          'manoeuvres': 1,
#          'solve': 5,
#          'stand': 14,
#          'off': 89,
#          'continue': 84,
#          'ruling': 30,
#          'liberal': 18,
#          'democratic': 17,
#          'party': 34,
#          'yesterday': 161,
#          'outlined': 12,
#          'package': 34,
#          'measures': 67,
#          'economy': 125,
#          'proposed': 106,
#          'include': 65,
#          'large': 70,
#          'supplementary': 5,
#          'budget': 117,
#          'record': 188,
#          'public': 84,
#          'works': 12,
#          'spending': 54,
#          'first': 447,
#          'half': 113,
#          'financial': 148,
#          'call': 28,
#          'stepped': 2,
#          'an': 844,
#          'emergency': 10,
#          'measure': 16,
#          'stimulate': 27,
#          'despite': 71,
#          'prime': 73,
#          'yasuhiro': 12,
#          'nakasone': 24,
#          'avowed': 1,
#          'fiscal': 90,
#          'reform': 31,
#          'program': 66,
#          'deputy': 16,
#          'representative': 19,
#          'michael': 12,
#          'smith': 12,
#          'makoto': 3,
#          'kuroda': 9,
#          'international': 221,
#          'miti': 17,
#          'due': 160,
#          'meet': 63,
#          'washington': 92,
#          'week': 334,
#          'effort': 31,
#          'end': 275,
#          'china': 106,
#          'daily': 65,
#          'says': 143,
#          'vermin': 2,
#          'eat': 2,
#          'grain': 130,
#          'stocks': 177,
#          'survey': 8,
#          'provinces': 6,
#          'seven': 147,
#          'cities': 4,
#          'showed': 48,
#          'consume': 3,
#          'each': 119,
#          'tonnes': 535,
#          'or': 553,
#          'fruit': 3,
#          'output': 107,
#          'left': 28,
#          'rot': 3,
#          'its': 1372,
#          'vegetables': 4,
#          'paper': 27,
#          'blamed': 7,
#          'waste': 14,
#          'inadequate': 10,
#          'storage': 18,
#          'bad': 6,
#          'preservation': 2,
#          'methods': 6,
#          'launched': 20,
#          'national': 197,
#          'programme': 13,
#          'reduce': 77,
#          'calling': 10,
#          'improved': 41,
#          'technology': 40,
#          'greater': 23,
#          'production': 289,
#          'additives': 2,
#          'gave': 44,
#          'no': 277,
#          'details': 57,
#          'revise': 8,
#          'energy': 93,
#          'demand': 177,
#          'downwards': 4,
#          'ministry': 108,
#          'supply': 158,
#          'outlook': 28,
#          'august': 39,
#          'forecast': 96,
#          'downtrend': 2,
#          'expected': 274,
#          'lower': 152,
#          'projection': 6,
#          'primary': 26,
#          'supplies': 60,
#          'kilolitres': 1,
#          'kl': 2,
#          'decision': 70,
#          'follows': 45,
#          'emergence': 1,
#          'structural': 8,
#          'changes': 43,
#          'following': 75,
#          'rise': 240,
#          'value': 106,
#          'yen': 193,
#          'decline': 74,
#          'domestic': 164,
#          'power': 30,
#          'planning': 24,
#          'work': 40,
#          'out': 148,
#          'revised': 45,
#          'through': 120,
#          'deliberations': 1,
#          'committee': 74,
#          'meetings': 29,
#          'agency': 38,
#          'natural': 50,
#          'resources': 43,
#          'review': 36,
#          'breakdown': 8,
#          'including': 101,
#          'oil': 586,
#          'nuclear': 2,
#          'gas': 158,
#          'provided': 25,
#          'bulk': 17,
#          'ended': 144,
#          'march': 315,
#          'supplying': 5,
#          'estimated': 105,
#          'kilowatt': 1,
#          'hour': 10,
#          'basis': 70,
#          'followed': 23,
#          'liquefied': 3,
#          'noted': 61,
#          'thai': 15,
#          'deficit': 213,
#          'widens': 3,
#          'quarter': 377,
#          'thailand': 27,
#          'widened': 6,
#          'baht': 3,
#          'ago': 129,
#          'economics': 9,
#          'department': 183,
#          'janunary': 1,
#          'rose': 227,
#          'climate': 4,
#          'resulted': 20,
#          'increase': 221,
#          'raw': 20,
#          'materials': 45,
#          'semi': 12,
#          'finished': 8,
#          'bill': 70,
#          'however': 137,
#          'fell': 126,
#          'prices': 387,
#          'expanded': 7,
#          'growth': 258,
#          'smaller': 17,
#          'than': 366,
#          'earnings': 177,
#          'key': 51,
#          'commodities': 30,
#          'rice': 72,
#          'declined': 61,
#          'maize': 41,
#          'sugar': 130,
#          'tin': 51,
#          'canned': 4,
#          'pineapples': 1,
#          'registering': 3,
#          'high': 150,
#          'were': 597,
#          'jewellery': 1,
#          'clothing': 4,
#          'rubber': 36,
#          'indonesia': 46,
#          'sees': 76,
#          'cpo': 5,
#          'price': 397,
#          'rising': 73,
#          'sharply': 46,
#          'expects': 98,
#          'crude': 160,
#          'palm': 32,
#          'tonne': 75,
#          'fob': 14,
#          'sometime': 3,
#          'better': 41,
#          'european': 121,
#          'fall': 111,
#          'malaysian': 11,
#          'hasrul': 1,
#          'harahap': 3,
#          'junior': 4,
#          'tree': 2,
#          'crops': 33,
#          'indonesian': 10,
#          'reporters': 47,
#          'sumatran': 1,
#          'now': 173,
#          'around': 164,
#          'cif': 7,
#          'delivery': 58,
#          'rotterdam': 13,
#          'traders': 133,
#          'maintain': 37,
#          'making': 73,
#          'recent': 102,
#          'purchases': 33,
#          'so': 103,
#          'possibly': 19,
#          'second': 82,
#          'producer': 59,
#          'after': 367,
#          'forced': 16,
#          'ensure': 9,
#          'during': 110,
#          'moslem': 1,
#          'fasting': 2,
#          'month': 250,
#          'ramadan': 2,
#          'cover': 28,
#          'temporary': 24,
#          'shortage': 20,
#          'lose': 7,
#          'calendar': 18,
#          'according': 54,
#          'central': 193,
#          'bank': 616,
#          'figures': 118,
#          'ship': 16,
#          'ban': 21,
#          'ends': 15,
#          'nsw': 10,
#          'ports': 18,
#          'tug': 5,
#          'crews': 3,
#          'wales': 5,
#          'victoria': 3,
#          'western': 68,
#          'lifted': 15,
#          'flag': 9,
#          'ships': 36,
#          'carrying': 12,
#          'containers': 2,
#          'still': 112,
#          'being': 97,
#          'disrupted': 7,
#          'separate': 19,
#          'shipping': 25,
#          'imposed': 26,
#          'pay': 151,
#          'claim': 8,
#          'prevented': 7,
#          'movement': 20,
#          'port': 50,
#          'nearly': 34,
#          'vessels': 20,
#          'went': 25,
#          'before': 141,
#          'hearing': 14,
#          'arbitration': 3,
#          'commission': 111,
#          'today': 275,
#          'disruption': 3,
#          'began': 46,
#          'cargo': 20,
#          'handling': 8,
#          'sydney': 5,
#          'newcastle': 3,
#          'kembla': 3,
#          'part': 96,
#          'called': 62,
#          'trades': 14,
#          'labour': 15,
#          'council': 58,
#          'protest': 9,
#          'state': 112,
#          'workers': 54,
#          'compensation': 12,
#          'laws': 14,
#          'various': 19,
#          'unions': 11,
#          'appear': 16,
#          'taking': 38,
#          'turn': 12,
#          'start': 100,
#          'shift': 10,
#          'then': 42,
#          'walk': 1,
#          'container': 4,
#          'movements': 9,
#          'most': 108,
#          'affected': 39,
#          'stopped': 9,
#          'altogether': 4,
#          'say': 97,
#          'how': 41,
#          'go': 43,
#          'what': 77,
#          'effect': 45,
#          'commodity': 49,
#          'may': 540,
#          'likely': 106,
#          'least': 45,
#          'paian': 1,
#          'nainggolan': 3,
#          'reuters': 92,
#          'telephone': 24,
#          'interview': 22,
#          'sawn': 1,
#          'timber': 5,
#          'pepper': 1,
#          'tobacco': 19,
#          'considered': 21,
#          'either': 22,
#          'refined': 23,
#          'introduced': 23,
#          'question': 19,
#          'rachmat': 1,
#          'saleh': 2,
#          'when': 169,
#          'ahead': 28,
#          'made': 174,
#          'fledgling': 1,
#          'currently': 57,
#          'coffee': 71,
#          'physicals': 3,
#          'outcry': 1,
#          'system': 102,
#          'four': 168,
#          'days': 128,
#          'several': 82,
#          'factors': 31,
#          'make': 91,
#          'cautiously': 2,
#          'slowly': 7,
#          'safely': 1,
#          'mistake': 2,
#          'undermine': 5,
#          'confidence': 21,
#          'physical': 9,
#          'added': 219,
#          'january': 106,
#          'contracts': 42,
#          'traded': 27,
#          'five': 245,
#          'forward': 29,
#          'robusta': 2,
#          'grades': 16,
#          'prompt': 2,
#          'board': 184,
#          'considering': 32,
#          'introduction': 10,
#          'futures': 64,
#          'later': 55,
#          'feasibility': 3,
#          'study': 28,
#          'needed': 50,
#          'decisions': 13,
#          'until': 62,
#          'elections': 6,
#          'monday': 25,
#          'should': 146,
#          'marketing': 72,
#          'hoped': 14,
#          'development': 89,
#          'help': 80,
#          'trying': 26,
#          'overseas': 25,
#          'building': 42,
#          'contacts': 5,
#          'users': 7,
#          'teams': 1,
#          'already': 82,
#          'encourage': 17,
#          'direct': 15,
#          'use': 119,
#          'delegation': 9,
#          'visit': 17,
#          'europe': 45,
#          'mexico': 22,
#          'latin': 4,
#          'states': 145,
#          'participation': 7,
#          'infant': 1,
#          'good': 71,
#          'although': 66,
#          'disappointing': 4,
#          'transactions': 24,
#          'december': 89,
#          'totalled': 26,
#          'worth': 51,
#          'plus': 32,
#          'rupiah': 3,
#          'delivered': 9,
#          'locally': 2,
#          'latest': 66,
#          'report': 209,
#          'amounted': 6,
#          'only': 175,
#          'lots': 4,
#          'valued': 15,
#          'total': 293,
#          'membership': 8,
#          'nine': 111,
#          'brokers': 25,
#          'sri': 14,
#          'lanka': 13,
#          'gets': 11,
#          'usda': 108,
#          'approval': 65,
#          'wheat': 189,
#          'food': 52,
#          'agriculture': 130,
#          'approved': 64,
#          'continental': 25,
#          'sale': 147,
#          'soft': 23,
#          'c': 76,
#          'f': 52,
#          'pacific': 39,
#          'northwest': 10,
#          'colombo': 6,
#          'shipment': 32,
#          'mining': 40,
#          'gold': 99,
#          'mine': 50,
#          'corp': 623,
#          'holdings': 56,
#          'wmng': 2,
#          'wmc': 6,
#          'establish': 5,
#          'joint': 55,
#          'venture': 46,
#          'northern': 19,
#          'territory': 2,
#          'about': 515,
#          'known': 23,
#          'goodall': 1,
#          'project': 14,
#          'owned': 125,
#          'local': 53,
#          'w': 17,
#          'r': 17,
#          'grace': 11,
#          'gra': 3,
#          'unit': 171,
#          'located': 15,
#          'kms': 2,
#          'east': 52,
#          'adelaide': 1,
#          'river': 23,
#          'mt': 11,
#          'bundey': 1,
#          'statement': 168,
#          'pit': 2,
#          'conventional': 3,
#          'leach': 1,
#          'treatment': 9,
#          'plant': 66,
#          'produce': 28,
#          'ounces': 17,
#          'mid': 26,
#          'annual': 101,
#          'ore': 24,
#          'capacity': 42,
#          'sumitomo': 16,
#          'aims': 6,
#          'quick': 7,
#          'recovery': 25,
#          'merger': 128,
#          'sumi': 1,
#          'certain': 63,
#          'status': 15,
#          'profitable': 21,
#          'result': 86,
#          'heiwa': 4,
#          'sogo': 4,
#          'analysts': 185,
#          'osaka': 2,
#          'based': 142,
#          'desposits': 1,
#          'trillion': 4,
#          'merged': 6,
#          'small': 40,
#          'struggling': 3,
#          'unrecoverable': 1,
#          'loans': 118,
#          'october': 53,
#          'link': 14,
#          'president': 137,
#          'koh': 1,
#          'komatsu': 9,
#          'confident': 9,
#          'his': 105,
#          'can': 116,
#          'regain': 1,
#          'position': 67,
#          'll': 4,
#          'back': 50,
#          'within': 63,
#          'three': 277,
#          'years': 159,
#          'initially': 8,
#          'profitability': 5,
#          'efficiency': 8,
#          'vastly': 1,
#          'branch': 10,
#          'network': 18,
#          'metropolitan': 4,
#          'area': 61,
#          'relatively': 16,
#          'weak': 24,
#          'divided': 9,
#          'whether': 52,
#          'gamble': 3,
#          'paid': 65,
#          'too': 53,
#          'debts': 4,
#          'others': 18,
#          'argue': 4,
#          'effective': 91,
#          'creating': 1,
#          'comparable': 10,
#          'scratch': 1,
#          'agreed': 155,
#          'aggressive': 8,
#          'entered': 32,
#          'lucrative': 4,
#          'securities': 151,
#          'geared': 2,
#          'competition': 21,
#          'questioned': 4,
#          'wisdom': 1,
#          'moves': 36,
#          've': 14,
#          'bold': 3,
#          'everything': 3,
#          'largely': 15,
#          'hands': 11,
#          'kleinwort': 5,
#          'benson': 2,
#          'simon': 3,
#          'smithson': 2,
#          'limits': 21,
#          'placed': 18,
#          'enter': 8,
#          'investment': 161,
#          'goldman': 5,
#          'sachs': 5,
#          'limited': 34,
#          'partnership': 30,
#          'federal': 145,
#          'reserve': 109,
#          'forbidden': 1,
#          'personnel': 7,
#          'tie': 4,
#          'widely': 7,
#          'looked': 5,
#          'lame': 1,
#          'duck': 1,
#          'fed': 165,
#          'stricter': 1,
#          'regulations': 12,
#          'change': 80,
#          'near': 41,
#          'future': 51,
#          'things': 7,
#          'wait': 4,
#          'st': 281,
#          'century': 13,
#          'willing': 13,
#          'patient': 4,
#          'routes': 7,
#          'into': 186,
#          'home': 43,
#          'article': 8,
#          'act': 32,
#          'version': 3,
#          'glass': 3,
#          'steagall': 1,
#          'separates': 2,
#          'banking': 54,
#          'walls': 1,
#          'crumbling': 1,
#          'hopes': 21,
#          'deregulation': 10,
#          'create': 7,
#          'opportunities': 12,
#          'need': 49,
#          'find': 22,
#          'chances': 5,
#          'cases': 12,
#          'these': 87,
#          'related': 28,
#          'trust': 56,
#          'occur': 10,
#          'focus': 16,
#          'bond': 50,
#          'dealing': 3,
#          'strengthening': 10,
#          'meiko': 1,
#          'holds': 32,
#          'optimistic': 18,
#          'entering': 8,
#          'here': 67,
#          'swiss': 40,
#          'universal': 8,
#          'subsidiary': 132,
#          'banca': 1,
#          'del': 9,
#          'gottardo': 2,
#          'finance': 112,
#          'grant': 6,
#          'licences': 12,
#          'subsidiaries': 19,
#          'banks': 149,
#          'soon': 36,
#          'parent': 26,
#          'less': 91,
#          'reluctant': 9,
#          'push': 14,
#          'don': 40,
#          'waves': 1,
#          'expect': 49,
#          'allowed': 22,
#          'like': 37,
#          'city': 38,
#          'pushing': 7,
#          'lending': 19,
#          'individuals': 8,
#          'medium': 27,
#          'businesses': 49,
#          'replace': 9,
#          'disappearing': 1,
#          'big': 15,
#          'devote': 1,
#          'lot': 16,
#          'digesting': 1,
#          'initiatives': 5,
#          'ailing': 3,
#          'strategies': 2,
#          'absorbing': 1,
#          'juggling': 1,
#          'next': 155,
#          'decade': 5,
#          'see': 58,
#          'strategy': 25,
#          'right': 33,
#          'wrong': 4,
#          'subroto': 3,
#          'supports': 6,
#          'extension': 24,
#          'mines': 25,
#          'confirmed': 22,
#          'support': 71,
#          'sixth': 10,
#          'agreement': 258,
#          'ita': 7,
#          'necessary': 24,
#          'clarify': 2,
#          'lapse': 2,
#          'ready': 15,
#          'seventh': 7,
#          'accord': 60,
#          'believe': 41,
#          'unnecessary': 2,
#          'expire': 17,
#          'june': 238,
#          'unless': 28,
#          'thirds': 5,
#          'majority': 24,
#          'members': 49,
#          'vote': 18,
#          'bundesbank': 84,
#          'allocates': 2,
#          'marks': 82,
#          'tender': 147,
#          'accepted': 23,
#          'bids': 33,
#          'repurchase': 49,
#          'fixed': 47,
#          ...})

# %%
# vocabulary size
total_count = len(unigram_dict)
total_count
# Out:
# 12580

# %%
# relative frequencies of each word
for word in counts:
    counts[word] /= float(total_count)

counts
# Out:
# Counter({'asian': 0.0010333863275039745,
#          'exporters': 0.004133545310015898,
#          'fear': 0.0006359300476947536,
#          'damage': 0.002305246422893482,
#          'from': 0.10882352941176471,
#          'u': 0.08879173290937997,
#          's': 0.22766295707472178,
#          'japan': 0.035055643879173294,
#          'rift': 7.94912559618442e-05,
#          'mounting': 0.000397456279809221,
#          'trade': 0.04364069952305247,
#          'friction': 0.0006359300476947536,
#          'between': 0.015182829888712241,
#          'the': 0.993322734499205,
#          'and': 0.36558028616852145,
#          'has': 0.07742448330683625,
#          'raised': 0.005564387917329093,
#          'fears': 0.0010333863275039745,
#          'among': 0.0034976152623211448,
#          'many': 0.004292527821939587,
#          'of': 0.5302861685214626,
#          'asia': 0.0011128775834658188,
#          "'": 0.16645468998410176,
#          'exporting': 0.0009538950715421304,
#          'nations': 0.005643879173290938,
#          'that': 0.10937996820349762,
#          'row': 0.0002384737678855326,
#          'could': 0.02313195548489666,
#          'inflict': 7.94912559618442e-05,
#          'far': 0.0043720190779014305,
#          'reaching': 0.0005564387917329094,
#          'economic': 0.019395866454689985,
#          'businessmen': 0.0011923688394276629,
#          'officials': 0.015103338632750398,
#          'said': 0.36955484896661367,
#          'they': 0.041176470588235294,
#          'told': 0.018839427662957074,
#          'reuter': 0.0021462639109697933,
#          'correspondents': 0.0002384737678855326,
#          'in': 0.4030206677265501,
#          'capitals': 0.0002384737678855326,
#          'a': 0.35071542130365657,
#          'move': 0.008028616852146264,
#          'against': 0.021462639109697933,
#          'might': 0.004689984101748808,
#          'boost': 0.003577106518282989,
#          'protectionist': 0.0017488076311605724,
#          'sentiment': 0.000794912559618442,
#          'lead': 0.007631160572337043,
#          'to': 0.5037360890302067,
#          'curbs': 0.0009538950715421304,
#          'on': 0.13060413354531,
#          'american': 0.01001589825119237,
#          'imports': 0.019236883942766295,
#          'their': 0.018282988871224166,
#          'products': 0.01589825119236884,
#          'but': 0.051669316375198726,
#          'some': 0.022098569157392688,
#          'while': 0.013036565977742448,
#          'conflict': 0.0002384737678855326,
#          'would': 0.07360890302066772,
#          'hurt': 0.0008744038155802862,
#          'them': 0.004610492845786964,
#          'long': 0.00945945945945946,
#          'run': 0.001669316375198728,
#          'short': 0.006915739268680445,
#          'term': 0.009538950715421303,
#          'tokyo': 0.005961844197138315,
#          'loss': 0.04825119236883943,
#          'be': 0.09260731319554849,
#          'gain': 0.008028616852146264,
#          'it': 0.15659777424483307,
#          'will': 0.0782193958664547,
#          'impose': 0.001589825119236884,
#          'mln': 0.24356120826709063,
#          'dlrs': 0.17011128775834658,
#          'tariffs': 0.006518282988871224,
#          'japanese': 0.015262321144674086,
#          'electronics': 0.001987281399046105,
#          'goods': 0.0054848966613672495,
#          'april': 0.03791732909379968,
#          'retaliation': 0.001589825119236884,
#          'for': 0.20604133545310016,
#          'alleged': 0.0008744038155802862,
#          'businesses': 0.0038950715421303657,
#          'replace': 0.0007154213036565977,
#          'disappearing': 7.94912559618442e-05,
#          'big': 0.0011923688394276629,
#          'devote': 7.94912559618442e-05,
#          'lot': 0.0012718600953895071,
#          'digesting': 7.94912559618442e-05,
#          'initiatives': 0.000397456279809221,
#          'ailing': 0.0002384737678855326,
#          'strategies': 0.0001589825119236884,
#          'absorbing': 7.94912559618442e-05,
#          'juggling': 7.94912559618442e-05,
#          'next': 0.01232114467408585,
#          'decade': 0.000397456279809221,
#          'see': 0.004610492845786964,
#          'strategy': 0.001987281399046105,
#          'right': 0.0026232114467408586,
#          'wrong': 0.0003179650238473768,
#          'subroto': 0.0002384737678855326,
#          'supports': 0.0004769475357710652,
#          'extension': 0.0019077901430842607,
#          'mines': 0.001987281399046105,
#          'confirmed': 0.0017488076311605724,
#          'support': 0.005643879173290938,
#          'sixth': 0.000794912559618442,
#          'agreement': 0.020508744038155804,
#          'ita': 0.0005564387917329094,
#          'necessary': 0.0019077901430842607,
#          'clarify': 0.0001589825119236884,
#          'lapse': 0.0001589825119236884,
#          'ready': 0.0011923688394276629,
#          'seventh': 0.0005564387917329094,
#          'accord': 0.0047694753577106515,
#          'believe': 0.003259141494435612,
#          'unnecessary': 0.0001589825119236884,
#          'expire': 0.0013513513513513514,
#          'june': 0.01891891891891892,
#          'unless': 0.0022257551669316376,
#          'thirds': 0.000397456279809221,
#          'majority': 0.0019077901430842607,
#          'members': 0.0038950715421303657,
#          'vote': 0.0014308426073131955,
#          'bundesbank': 0.006677265500794912,
#          'allocates': 0.0001589825119236884,
#          'marks': 0.006518282988871224,
#          'tender': 0.011685214626391096,
#          'accepted': 0.0018282988871224164,
#          'bids': 0.0026232114467408586,
#          'repurchase': 0.0038950715421303657,
#          'fixed': 0.003736089030206677,
#          ...})

# %%
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
# predict the next word
dict(model["they", "told"])
# Out:
# {'reuter': 0.3333333333333333,
#  'reporters': 0.3333333333333333,
#  'reuters': 0.3333333333333333}

# %%
# another example
dict(model["they", "are"])
# Out:
# {'more': 0.034482758620689655,
#  'prepared': 0.034482758620689655,
#  'giving': 0.034482758620689655,
#  'rumors': 0.034482758620689655,
#  'to': 0.034482758620689655,
#  'pleased': 0.034482758620689655,
#  'a': 0.034482758620689655,
#  'not': 0.13793103448275862,
#  'saying': 0.034482758620689655,
#  'trading': 0.034482758620689655,
#  'free': 0.034482758620689655,
#  'today': 0.034482758620689655,
#  'beginning': 0.034482758620689655,
#  'at': 0.034482758620689655,
#  'willing': 0.06896551724137931,
#  'happy': 0.034482758620689655,
#  'required': 0.034482758620689655,
#  'polysaturated': 0.034482758620689655,
#  'defeathered': 0.034482758620689655,
#  'fired': 0.06896551724137931,
#  'imported': 0.034482758620689655,
#  'unprofitable': 0.034482758620689655,
#  'being': 0.034482758620689655,
#  'less': 0.034482758620689655}
